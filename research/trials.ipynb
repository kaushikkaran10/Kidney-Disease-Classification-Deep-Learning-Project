# %%
d= {"key":"val","key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d2
#
# NameError: name 'd2' is not defined
